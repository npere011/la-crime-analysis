# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import find_peaks
import geopandas as gpd

# %% [markdown]
# # Los Angeles Crime from 2020 to present
#
# ## Data Sources
#
# * [LA City Crime Dataset](https://data.lacity.org/Public-Safety/Crime-Data-from-2020-to-Present/2nrs-mtv8/about_data)
# * [LA City Geographical Dataset](https://geohub.lacity.org/datasets/19a8293551974116b76533e984dd9260/about)

# %% [markdown]
# ## Executive Summary
# This project analyzed crime data from Los Angeles between 2020 and the present to identify patterns, trends, and actionable insights for improving public safety. Leveraging Python, the analysis focused on crime frequency, weapon use, victim demographics, and spatial-temporal patterns. The study found that property crimes were the most prevalent, with certain areas experiencing higher crime rates than others. Insights from this project can inform law enforcement resource allocation, public safety campaigns, and crime prevention strategies. Future studies could enhance these findings by integrating socio-economic factors and predictive analytics.
#
# #### About the data
# The data set has more than 900,000 rows of information provided by the Los Angeles Police Department. This data contains information about crime in Los Angeles from 2020 to present, such as, reported crimes, victim ages, and statuses of the investigations.
#
# ## Questions:
# 1. What are the most common crimes reported? (Top 10)
# 2. What weapons were used in the crimes reported? (Top 10)
# 3. What areas have the most amount of reported crime? (Top 10)
# 4. What time of day are the most amount of reported crimes occuring?
# 5. What day of the week has the most reported crime?
# 6. What were the victims' sexes?
# 7. What age groups did the victims belong to?
# 8. How does the count of victims change with age and sex?
# 9. What are the victims' descent?
# 10. What are the statuses of the reported crime?
# 11. What year had the most crime?

# %% [markdown]
# ## Data Setup
#
# Run this section before anything else

# %%
# Reading in the data
lacrime_df= pd.read_csv("C:/Users/perez/Downloads/Crime_Data_from_2020_to_Present_2024.csv")

# Dropping columns of information that aren't used in this analysis
lacrime_df.drop(['Crm Cd 1','Crm Cd 2','Crm Cd 3','Crm Cd 4','Cross Street','Status',
                 'LAT','LON','Weapon Used Cd','Mocodes','Part 1-2'],axis=1,inplace=True)

# %%
# Adjusting Victim Sex column to fill in unknowns and nonapplicables with 'X'
lacrime_df['Vict Sex']=lacrime_df['Vict Sex'].replace('H','X')
lacrime_df['Vict Sex']=lacrime_df['Vict Sex'].replace('-','X')
lacrime_df['Vict Sex']= lacrime_df['Vict Sex'].fillna('X')
lacrime_df['Vict Sex']=lacrime_df['Vict Sex'].replace('F','Female')
lacrime_df['Vict Sex']=lacrime_df['Vict Sex'].replace('M','Male')

# %%
# Adjusting Victim Descent column to fill in unknowns and nonapplicables with 'X'
lacrime_df['Vict Descent']= lacrime_df['Vict Descent'].replace('-','X')
lacrime_df['Vict Descent']= lacrime_df['Vict Descent'].fillna('X')

# Replacing shorthand descent code with actual descent name as defined by LAPD
replacements={'H':'Hispanic/Latin/Mexican','B':'Black','W':'White','A':'Other Asian','K':'Korean','C':'Chinese','F':'Filipino',
             'J':'Japanese','I':'American Indian/Alaskan Native','V':"Vietnamese",'S':'Samoan','P':'Pacific Islander',
             'Z':'Asian Indian','G':'Guamanian','U':'Hawaiian','D':'Cambodain','L':'Laotian','X':'Unknown','O':'Other'}
lacrime_df['Vict Descent']= lacrime_df['Vict Descent'].replace(replacements)

# %%
def timeofday(time):
    occ= time    
    if time >=0 and time <600:
        return 'Late night: 12am to 6am'
    if time >=600 and time <1200:
        return 'Morning: 6am to 12pm'
    if time >=1200 and time <1800:
        return 'Afternoon: 12pm to 6pm'
    if time >=1800 and time <2359:
        return 'Evening/Night: 6pm to 12am'       
# Using the function to add a new column containing time of day from time crime occurred
lacrime_df['Time Crime Occ']= lacrime_df['TIME OCC'].apply(timeofday)

# %%
# Adding a new column, day of the week the crime occurred
lacrime_df['DATE OCC']= pd.to_datetime(lacrime_df['DATE OCC'], format="%m/%d/%Y %I:%M:%S %p")
lacrime_df['Day of the Week']=lacrime_df['DATE OCC'].dt.day_name()
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
lacrime_df['Day of the Week'] = pd.Categorical(lacrime_df['Day of the Week'], categories=weekday_order, ordered=True)

# %%
# Adding a new column, year crime occurred
lacrime_df['Year']= pd.DatetimeIndex(lacrime_df['DATE OCC']).year

# %%
# Finding instances where age is 0 or less and crime description contains 'child', 'minor', or 'chld'
# and replacing age with -7, an arbritrary number, as specific age can't be inferred but age group can
lacrime_df.loc[(lacrime_df['Vict Age'] <=0 )&(lacrime_df['Crm Cd Desc'].str.contains(r'chld|child|minor', case=False, na=False)),'Vict Age']= -7

# %%
def agegroup(victim):
    age= victim    
    if age == -7 or age <18 and age > 0:
        return 'Minors: 0 to 17 y/o'
    if age > 17 and age < 27:
        return 'Young Adults:18 to 26 y/o'
    if age < 1:
        return 'X'
    if age < 55 and age >26:
        return 'Adults: 27 to 54 y/o'
    else:
        return 'Seniors: 55+ y/o'
# Using the function to add a new column Age Group from victim age
lacrime_df['Age Group']=lacrime_df['Vict Age'].apply(agegroup)
ageorder=['Minors: 0 to 17 y/o','Young Adults:18 to 26 y/o','Adults: 27 to 54 y/o','Seniors: 55+ y/o']

# %%
# Create new data frame age1 grouping victims by age and sex, and including count
age1= lacrime_df.groupby(['Vict Age','Vict Sex']).size().reset_index(name='count')
age1= age1[(age1['Vict Age']>0) & (age1['Vict Sex'] != 'X')]

# Code used to find certain points on the lineplot
# Separate the data by sex
female_data= age1[age1['Vict Sex'] == 'Female'][['Vict Age','count']].rename(columns={'count':'female_count'})
male_data= age1[age1['Vict Sex'] == 'Male'][['Vict Age','count']].rename(columns={'count':'male_count'})

# Merge the datasets on 'Vict Age'
merged_data= pd.merge(female_data, male_data,on='Vict Age',how='inner')

# Find male peaks
male_peaks, _= find_peaks(merged_data['male_count'],threshold=500)
male_peak_values= merged_data.iloc[male_peaks][['Vict Age','male_count']]

# Find the maximum for female count
female_max_value= merged_data.loc[merged_data['female_count'].idxmax()]

# %%
# Read in geodata for the 21 patrol divisions
lapd= gpd.read_file("C:/Users/perez/Downloads/LAPD_Reporting_Districts.geojson")

# Getting rid of columns that won't be used
lapd= lapd[['APREC','geometry']]

# Replacing column name to match la crime data column name
lapd.rename(columns={'APREC':'AREA NAME'}, inplace=True)

# Dissolving borders to have 21 patrol divisions
lapd = lapd.dissolve(by='AREA NAME')
lapd.reset_index(inplace=True)

# Replacing 21 patrol division names to match la crime data names
update_areas= {'PACIFIC':'Pacific','DEVONSHIRE':'Devonshire','WEST LOS ANGELES':'West LA','NORTHEAST':'Northeast',
'HOLLENBECK':'Hollenbeck','MISSION':'Mission','FOOTHILL':'Foothill', 'NORTH HOLLYWOOD':'N Hollywood','SOUTHWEST': 'Southwest',         
'WILSHIRE':'Wilshire','TOPANGA':'Topanga','OLYMPIC':'Olympic','CENTRAL':'Central', 'WEST VALLEY':'West Valley', 'HARBOR':'Harbor',           
'NEWTON':'Newton', 'RAMPART':'Rampart','VAN NUYS':'Van Nuys','77TH STREET':'77th Street','HOLLYWOOD':'Hollywood','SOUTHEAST':'Southeast'}  
lapd.replace(update_areas,inplace=True)

# %%
# Creating new dataframe by area name and count, the count will be the density on the map
areas= lacrime_df.groupby(['AREA NAME']).size().reset_index(name='count').sort_values(by='count', ascending=False)

# Merging lapd and areas into one dataframe
lapdareas= lapd.merge(areas, on='AREA NAME')

# Ordering areas from highest count to lowest count
lapdareas.sort_values(by='count',ascending=False, inplace=True)

# Add new column Rank to rank areas from highstest count to lowest count
lapdareas['Rank']= range(1,len(lapdareas)+1)

# %% [markdown]
# ## Findings
# This section contains the answers to the questions posed.

# %% [markdown]
# ### Question 1: What are the most common crimes reported? (Top 10)

# %%
sns.set(style="whitegrid")
crimes = lacrime_df.pivot_table(index='Crm Cd Desc',
                                aggfunc='size').reset_index(name='Number of cases').sort_values(by='Number of cases',ascending=False)
sns.catplot(data=crimes.head(10), x='Number of cases',y='Crm Cd Desc', height=6,aspect=2,kind='bar')
plt.title("Top 10 Crimes reported",fontsize=25)
plt.ylabel('Crime Description',fontsize=20)
plt.xlabel('Count of reported crimes',fontsize=20)
averagec= crimes['Number of cases'].head(10).mean()
plt.axvline(averagec, color='red', linestyle='--', label=f'Top 10 Average:{averagec:.2f}')
plt.legend()
plt.xticks(range(0,110001, 10000))
plt.show()

# %% [markdown]
# #### Description
#
# The data shows that certain types of offenses, such as theft and assault, appear consistently at the top. This trend highlights which crime types are most prevalent in LA, providing insight into areas where increased preventative measures could be beneficial.

# %% [markdown]
# ### Question 2: What weapons were used in the crimes reported (Top 10)

# %%
weaponsx= lacrime_df.pivot_table(index='Weapon Desc', aggfunc='size').reset_index(name='count').sort_values('count',ascending=False)
weaponsx = weaponsx[(weaponsx['Weapon Desc'] !=
                     'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)') &(weaponsx['Weapon Desc'] !='VERBAL THREAT')].head(10)
sns.catplot(data=weaponsx.head(10), y='Weapon Desc', x='count',kind='bar',height=5,aspect=2)
plt.title("Top 10 weapons used in reported crimes*",fontsize=25)
plt.ylabel('Weapon',fontsize=20)
plt.xlabel('Count of times used',fontsize=20)
plt.xticks(range(0,35001,2500),fontsize=9)
averagewx= weaponsx['count'].head(10).mean()
plt.axvline(averagewx, color='red', linestyle='--', label=f'Top 10 Average:{averagewx:.2f}')
plt.legend()
plt.show()

# %% [markdown]
# #### Description
#
# This chart highlights patterns in weapon use, with firearms and knives being the most frequently involved. Understanding weapon types can aid in tailoring responses and interventions, such as increased firearm regulation or targeted law enforcement strategies. The LAPD categorizes "strong-arm" incidents as those involving hands, fists, feet, bodily force, or verbal threats; however, these were not included in this analysis due to their broader and less quantifiable nature.

# %% [markdown]
# ### Question 3: What areas have the most amount of reported crime? (Top 10)

# %%
sns.catplot(data=areas.head(10),x='count', y='AREA NAME',height=6,aspect=2,kind='bar')
plt.title('Top 10 Areas with most reported crimes',fontsize=25)
plt.ylabel('Area Name',fontsize=20)
plt.xlabel('Count of reported crimes',fontsize=20)
averagea= areas['count'].head(10).mean()
plt.axvline(averagea, color='red', linestyle='--', label=f'Top 10 Average:{averagea:.2f}')
plt.legend()
plt.xticks(range(0,70001,5000))
plt.show()

# %%
lapdareas= lapdareas.to_crs(epsg=2229)
lapdareas.plot(column='count', legend=True,figsize=(7,7),cmap='crest')
for x, y, label in zip(lapdareas.geometry.centroid.x, lapdareas.geometry.centroid.y, lapdareas['Rank'][lapdareas['Rank']<11]):
    plt.text(x, y, label, ha='center', va='center',color='white')
plt.title('Top 10: Crime Count Density Map by 21 Patrol Divisions',fontsize=25)
plt.grid(False)
plt.show()

# %% [markdown]
# The LAPD has 21 geographical areas know as patrol divisions. This data identifies crime hotspots, indicating where resource allocation for policing and community programs could be most impactful. It's interesting to observe that the top 10 crime areas are in a concentrated location.

# %% [markdown]
# ### Question 4: What time of day are the most amount of reported crimes occuring?

# %%
timeorder= ['Late night: 12am to 6am','Morning: 6am to 12pm','Afternoon: 12pm to 6pm','Evening/Night: 6pm to 12am']
sns.catplot(data=lacrime_df,x='Time Crime Occ',kind='count',height=6,aspect=2,order=timeorder)
plt.title('Time of day reported crime occured',fontsize=25)
plt.ylabel('Count of reported crimes',fontsize=20)
plt.xlabel('Time of Day',fontsize=20)
averagepd= lacrime_df['Time Crime Occ'].value_counts().mean()
plt.axhline(averagepd,color='red',linestyle='--',label=f'Average:{averagepd:.2f}')
plt.legend()
plt.show()

# %% [markdown]
# The data shows spikes in the afternoon and night hours. This can help  inform strategies around lighting, patrols, or community awareness initiatives during high-crime hours. There is a potential to divided the days in short timeframes and highlight more specific peaks in crimes reported.

# %% [markdown]
# ### Question 5: What day of the week has the most reported crime?

# %%
sns.catplot(data=lacrime_df,x='Day of the Week',kind='count',height=5,aspect=2)
plt.title('Day of the week: Count of reported crimes',fontsize=25)
plt.ylabel('Count of crimes reported',fontsize=20)
plt.xlabel('Day of the Week',fontsize=20)
averagedw=lacrime_df['Day of the Week'].value_counts().mean()
plt.axhline(averagedw,color='red',linestyle='--',label=f'Average:{averagedw:.2f}')
plt.legend()
plt.show()

# %% [markdown]
# Certain days, like weekends, may see increased crime rates, potentially linked to social behavior or events. These insights can guide police shifts or community activities aimed at crime prevention on specific days.

# %% [markdown]
# ### Question 6: What were the victims' sexes?

# %%
sns.catplot(data=lacrime_df, x='Vict Sex',kind='count')
plt.title('Count of reported crimes by sex',fontsize=25)
plt.xlabel('Victim Sex',fontsize=20)
plt.ylabel('Count of reported crimes',fontsize=20)
plt.show()

# %% [markdown]
# The data shows that males are more often the victims. It's interesting to see that there is a big percentage of unkown or nonapplicable victims.

# %% [markdown]
# ### Question 7: What age groups did the victims belong to?

# %%
plt.figure(figsize=(12, 6))
ax= sns.countplot(data=lacrime_df[lacrime_df['Age Group'] != 'X'], x='Age Group',order=ageorder)
plt.title('Count of victims by age group',fontsize=25)
plt.xlabel('Age Group',fontsize=20)
plt.ylabel('Count of victims',fontsize=20)
for p in ax.patches:  
    ax.text(p.get_x() + p.get_width() / 2, 
            p.get_height() + 2, 
            f'{int(p.get_height())}', 
            ha='center', va='bottom', fontsize=12)
plt.show()

# %% [markdown]
# The data shows that adults have the highest rate of victimhood. It is important to note that the adult bar may be the biggest due to the fact the this category contains a larger population.

# %% [markdown]
# ### Question 8: How does the count of victims change with age and sex?

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=merged_data, x='Vict Age', y='female_count', label='Female')
sns.lineplot(data=merged_data, x='Vict Age', y='male_count', label='Male')
plt.scatter(male_peak_values['Vict Age'], male_peak_values['male_count'], color='orange', label='Male Peaks')
plt.scatter(female_max_value['Vict Age'], female_max_value['female_count'], color='purple', label='Female Max', marker='o')
plt.scatter(34,9497, color='red', label='Change in trend')
plt.scatter(77,795, color='red')
plt.title('Count of victims over age by sex', fontsize=25)
plt.xlabel('Victim Age',fontsize=20)
plt.ylabel('Count of victims',fontsize=20)
plt.xticks(range(min(merged_data['Vict Age'])-2, max(merged_data['Vict Age'])+1, 5))
plt.yticks(range(0,13000,1000))
plt.legend()
plt.show()

# %% [markdown]
# The data shows that females up until the age of 34 tend to be the victims of crime in Los Angeles. Between the ages of 34 and 77 males experience a higher rate of victimization. After age 77, crime victimhood becomes more evenly distributed between males and females. Noteably there are 3 significant spikes for male victimhood at ages 30, 35, and 50.

# %% [markdown]
# ### Question 9: What are the victims' descent?

# %%
victdescent= lacrime_df['Vict Descent'][
(lacrime_df['Vict Descent']!='O')&(lacrime_df['Vict Descent'] !='X')].value_counts().reset_index().rename(columns={'Vict Descent':'Vict',0:'count'})
sns.catplot(data=victdescent.head(), y='Vict',x='count',kind='bar',height=6,aspect=2)
plt.title('Top 5 Victim Descent',fontsize=25)
plt.xlabel('Count of reported crimes',fontsize=20)
plt.ylabel('Victim Descent',fontsize=20)
plt.xticks(range(0,300001,25000))
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# This breakdown provides deeper insights into cultural or socioeconomic factors possibly affecting crime rates within specific communities, helping to direct social services and safety initiatives. Although Los Angeles contains a diverse population, the descents not shown make up a small percentage of victims.

# %% [markdown]
# ### Question 10: What are the statuses of the reported crime?

# %%
g= sns.catplot(data=lacrime_df, x='Status Desc', kind='count', height=6, aspect=2)
plt.title('Status of reported crime',fontsize=25)
plt.ylabel('Count of reported crime',fontsize=20)
plt.xlabel('Status',fontsize=20)
for ax in g.axes.flat:
    for p in ax.patches:
        ax.annotate(f'{p.get_height():,.0f}',
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=12, color='black',
                    xytext=(0, 5), textcoords='offset points')
plt.show()

# %% [markdown]
# There exists an overwhelming majority of cases marked as 'Investigation Continued.' This distribution highlights the ongoing nature of investigations and the lower frequency of resolution.

# %% [markdown]
# ### Question 11: What year had the most crime?

# %%
sns.catplot(data=lacrime_df, x='Year',kind='count',height=6,aspect=2)
plt.title('Count of reported crimes per year',fontsize=25)
plt.ylabel('Count of reported crimes',fontsize=20)
plt.xlabel('Year',fontsize=20)
averagey= lacrime_df['Year'][lacrime_df['Year'] != 2024].value_counts().mean()
plt.axhline(averagey,color='red',linestyle='--',label=f'2020 - 2023 Average:{averagey:.2f}')
plt.legend()
plt.show()

# %% [markdown]
# The data shows a slight increase in reported crimes since 2020, this could be related to the pandemic and could provide context for the change in crimes. It will be interesting to see the final result of 2024.

# %% [markdown]
# ## Exploratory Data Analysis
#
# For those interested in the steps I took in understanding the data, the following sections contain a more in depth explanation of the code.

# %% [markdown]
# ### LA crime data 2020 to present

# %% [markdown]
# https://data.lacity.org/Public-Safety/Crime-Data-from-2020-to-Present/2nrs-mtv8/about_data

# %% [markdown]
# The data used in this analysis is found in the website above. The webiste includes a detailed description of the column headers.

# %%
# Reading in the same data under a new name to show steps taken to create charts
lacrime= pd.read_csv("C:/Users/perez/Downloads/Crime_Data_from_2020_to_Present_2024.csv")

# %%
# We first look at how much information we have and the column names of the dataframe
# We can see some of these columns contain a lot of null values
lacrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990293 entries, 0 to 990292
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           990293 non-null  int64
#  1   Date Rptd       990293 non-null  object
#  2   DATE OCC        990293 non-null  object
#  3   TIME OCC        990293 non-null  int64
#  4   AREA            990293 non-null  int64
#  5   AREA NAME       990293 non-null  object
#  6   Rpt Dist No     990293 non-null  int64
#  7   Part 1-2        990293 non-null  int64
#  8   Crm Cd          990293 non-null  int64
#  9   Crm Cd Desc     990293 non-null  object
#  10  Mocodes         842641 non-null  object
#  11  Vict Age        990293 non-null  int64
#  12  Vict Sex        849515 non-null  object
#  13  Vict Descent    849504 non-null  object
#  14  Premis Cd       989970 non-null  float64
#  15  Premis Desc     989399 non-null  object
#  16  Weapon Used Cd  326547 non-null  float64
#  17  Weapon Desc     326547 non-null  object
#  18  Status          990292 non-null  object
#  19  Status Desc     990293 non-null  object
#  20  Crm Cd 1        990282 non-null  float64
#  21  Crm Cd 2        68957 non-null   float64
#  22  Crm Cd 3        2311 non-null    float64
#  23  Crm Cd 4        64 non-null      float64
#  24  LOCATION        990293 non-null  object
#  25  Cross Street    152641 non-null  object
#  26  LAT             990293 non-null  float64
#  27  LON             990293 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 211.5+ MB

# %%
# Looking at the values of the first 5 rows
lacrime.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# 2                             BIKE - STOLEN  ...     IC   Invest Cont
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC   Invest Cont
# 4                         THEFT OF IDENTITY  ...     IC   Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    510.0    998.0       NaN      NaN
# 1    330.0    998.0       NaN      NaN
# 2    480.0      NaN       NaN      NaN
# 3    343.0      NaN       NaN      NaN
# 4    354.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
# 2   1400 W  37TH                         ST          NaN  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR          NaN  34.1576 -118.4387
# 4                         1900    TRANSIENT          NaN  34.0944 -118.3277
#
# [5 rows x 28 columns]

# %% [markdown]
# Looking through the data and knowing the questions posed there are columns that won't be used in this analysis. Some of the columns are redundant as they provide a code used to identify a weapon or specific crime, but don't help give insight as to what it means. In the next step we drop all of those columns.

# %%
# Dropping columns of information that aren't used in this analysis
lacrime.drop(['Crm Cd 1','Crm Cd 2','Crm Cd 3','Crm Cd 4','Cross Street','Status',
                 'LAT','LON','Weapon Used Cd','Mocodes','Part 1-2'],axis=1,inplace=True)

# %% [markdown]
# ### Crimes

# %%
# Let's look at the unique values of the reported crimes
lacrime['Crm Cd Desc'].unique()
# Out:
# array(['VEHICLE - STOLEN', 'BURGLARY FROM VEHICLE', 'BIKE - STOLEN',
#        'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)', 'THEFT OF IDENTITY',
#        'BATTERY - SIMPLE ASSAULT',
#        'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH',
#        'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#        'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#        'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
#        'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#        'CHILD ANNOYING (17YRS & UNDER)',
#        'THEFT PLAIN - PETTY ($950 & UNDER)', 'LEWD CONDUCT',
#        'THEFT PLAIN - ATTEMPT', 'BURGLARY',
#        'THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)',
#        'BATTERY WITH SEXUAL CONTACT', 'INTIMATE PARTNER - SIMPLE ASSAULT',
#        'ROBBERY', 'BUNCO, GRAND THEFT',
#        'INTIMATE PARTNER - AGGRAVATED ASSAULT', 'ORAL COPULATION',
#        'UNAUTHORIZED COMPUTER ACCESS',
#        'SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ',
#        'VIOLATION OF RESTRAINING ORDER',
#        'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#        'OTHER MISCELLANEOUS CRIME', 'ARSON', 'BRANDISH WEAPON',
#        'DOCUMENT FORGERY / STOLEN FELONY',
#        'SEX OFFENDER REGISTRANT OUT OF COMPLIANCE', 'RAPE, FORCIBLE',
#        'VANDALISM - MISDEAMEANOR ($399 OR UNDER)',
#        'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
#        'CREDIT CARDS, FRAUD USE ($950.01 & OVER)',
#        'THREATENING PHONE CALLS/LETTERS',
#        'SEXUAL PENETRATION W/FOREIGN OBJECT', 'EXTORTION',
#        'OTHER ASSAULT', 'PICKPOCKET', 'DISTURBING THE PEACE',
#        'BUNCO, ATTEMPT', 'HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE',
#        'PIMPING', 'PEEPING TOM', 'VIOLATION OF COURT ORDER',
#        'CONTEMPT OF COURT', 'FALSE POLICE REPORT', 'CONTRIBUTING',
#        'FALSE IMPRISONMENT',
#        'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT', 'ATTEMPTED ROBBERY',
#        'CREDIT CARDS, FRAUD USE ($950 & UNDER', 'CHILD STEALING',
#        'LEWD/LASCIVIOUS ACTS WITH CHILD',
#        'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)', 'INDECENT EXPOSURE',
#        'CHILD NEGLECT (SEE 300 W.I.C.)', 'STALKING',
#        'DISHONEST EMPLOYEE - GRAND THEFT', 'TRESPASSING',
#        'BURGLARY, ATTEMPTED', 'RAPE, ATTEMPTED',
#        'DISCHARGE FIREARMS/SHOTS FIRED',
#        'HUMAN TRAFFICKING - COMMERCIAL SEX ACTS',
#        'VEHICLE - ATTEMPT STOLEN', 'PANDERING',
#        'FIREARMS RESTRAINING ORDER (FIREARMS RO)', 'RESISTING ARREST',
#        'BURGLARY FROM VEHICLE, ATTEMPTED', 'THEFT, PERSON',
#        'BATTERY POLICE (SIMPLE)',
#        'VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, BIKES, ETC)',
#        'THEFT FROM PERSON - ATTEMPT', 'FAILURE TO YIELD', 'BOMB SCARE',
#        'ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER',
#        'BUNCO, PETTY THEFT', 'SHOTS FIRED AT INHABITED DWELLING',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 & UNDER',
#        'KIDNAPPING - GRAND ATTEMPT',
#        'SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT',
#        'TILL TAP - GRAND THEFT ($950.01 & OVER)',
#        'VIOLATION OF TEMPORARY RESTRAINING ORDER',
#        'THROWING OBJECT AT MOVING VEHICLE',
#        'DOCUMENT WORTHLESS ($200.01 & OVER)', 'KIDNAPPING',
#        'CRIMINAL HOMICIDE', 'PURSE SNATCHING',
#        'THEFT FROM MOTOR VEHICLE - ATTEMPT',
#        'DISHONEST EMPLOYEE - PETTY THEFT', 'CHILD PORNOGRAPHY',
#        'WEAPONS POSSESSION/BOMBING',
#        'DRIVING WITHOUT OWNER CONSENT (DWOC)',
#        'REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)',
#        'LYNCHING', 'RECKLESS DRIVING', 'SHOPLIFTING - ATTEMPT',
#        'COUNTERFEIT',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01',
#        'BATTERY ON A FIREFIGHTER', 'CRUELTY TO ANIMALS', 'BOAT - STOLEN',
#        'ILLEGAL DUMPING', 'PROWLER', 'DRUGS, TO A MINOR',
#        'THEFT, COIN MACHINE - PETTY ($950 & UNDER)',
#        'DOCUMENT WORTHLESS ($200 & UNDER)', 'MANSLAUGHTER, NEGLIGENT',
#        'PETTY THEFT - AUTO REPAIR', 'THEFT, COIN MACHINE - ATTEMPT',
#        'TILL TAP - PETTY ($950 & UNDER)', 'PURSE SNATCHING - ATTEMPT',
#        'LYNCHING - ATTEMPTED', 'BIKE - ATTEMPTED STOLEN', 'CONSPIRACY',
#        'GRAND THEFT / AUTO REPAIR', 'BRIBERY',
#        'GRAND THEFT / INSURANCE FRAUD', 'DRUNK ROLL', 'CHILD ABANDONMENT',
#        'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)', 'DISRUPT SCHOOL',
#        'PICKPOCKET, ATTEMPT', 'TELEPHONE PROPERTY - DAMAGE',
#        'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM',
#        'BIGAMY', 'FAILURE TO DISPERSE',
#        'FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)',
#        'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)',
#        'BLOCKING DOOR INDUCTION CENTER', 'INCITING A RIOT',
#        'DISHONEST EMPLOYEE ATTEMPTED THEFT', 'TRAIN WRECKING',
#        'DRUNK ROLL - ATTEMPT'], dtype=object)

# %% [markdown]
# There are over 100 unique crimes committed. Although many of the crimes seem similar, California and the LAPD have distinctions between crimes. For example grand theft insurance fraud and grand theft auto repair fall under seperate crimes.

# %%
# We can see an ordered list of how many times crimes have been reported
lacrime['Crm Cd Desc'].value_counts()
# Out:
# Crm Cd Desc
# VEHICLE - STOLEN                                           112502
# BATTERY - SIMPLE ASSAULT                                    74747
# BURGLARY FROM VEHICLE                                       61944
# THEFT OF IDENTITY                                           61413
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     60082
#                                                             ...
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)              5
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                        4
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              4
# TRAIN WRECKING                                                  1
# DRUNK ROLL - ATTEMPT                                            1
# Name: count, Length: 140, dtype: int64

# %% [markdown]
# The count of many of the crimes are in the single digits or a significantly smaller than the rest of the values. This is why I chose to show the top 10 crimes committed.

# %% [markdown]
# ### Weapons

# %%
# We can look at all of the unique weapons used in some of the crimes
lacrime['Weapon Desc'].unique()
# Out:
# array([nan, 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)', 'VEHICLE',
#        'UNKNOWN WEAPON/OTHER WEAPON', 'VERBAL THREAT',
#        'BELT FLAILING INSTRUMENT/CHAIN', 'HAND GUN', 'UNKNOWN FIREARM',
#        'KNIFE WITH BLADE 6INCHES OR LESS', 'FIXED OBJECT',
#        'KITCHEN KNIFE', 'MACHETE', 'UNKNOWN TYPE CUTTING INSTRUMENT',
#        'MACE/PEPPER SPRAY', 'STICK', 'OTHER KNIFE', 'PHYSICAL PRESENCE',
#        'KNIFE WITH BLADE OVER 6 INCHES IN LENGTH', 'HAMMER',
#        'AIR PISTOL/REVOLVER/RIFLE/BB GUN', 'SEMI-AUTOMATIC PISTOL',
#        'SIMULATED GUN', 'RAZOR', 'OTHER FIREARM', 'FOLDING KNIFE',
#        'PIPE/METAL PIPE', 'ROCK/THROWN OBJECT', 'RIFLE',
#        'OTHER CUTTING INSTRUMENT', 'FIRE', 'REVOLVER', 'BOTTLE',
#        'SCISSORS', 'SWITCH BLADE', 'BRASS KNUCKLES', 'CLUB/BAT',
#        'BLUNT INSTRUMENT', 'BOARD', 'STUN GUN', 'CLEAVER', 'RAZOR BLADE',
#        'SCREWDRIVER', 'SHOTGUN', 'CONCRETE BLOCK/BRICK',
#        'CAUSTIC CHEMICAL/POISON', 'SEMI-AUTOMATIC RIFLE',
#        'SCALDING LIQUID', 'TIRE IRON', 'BOWIE KNIFE', 'GLASS', 'AXE',
#        'TOY GUN', 'BOMB THREAT', 'SAWED OFF RIFLE/SHOTGUN',
#        'MARTIAL ARTS WEAPONS', 'DEMAND NOTE', 'DIRK/DAGGER',
#        'ASSAULT WEAPON/UZI/AK47/ETC', 'ROPE/LIGATURE',
#        'HECKLER & KOCH 93 SEMIAUTOMATIC ASSAULT RIFLE',
#        'EXPLOXIVE DEVICE', 'SWORD', 'MAC-11 SEMIAUTOMATIC ASSAULT WEAPON',
#        'SYRINGE', 'BOW AND ARROW', 'LIQUOR/DRUGS',
#        'DOG/ANIMAL (SIC ANIMAL ON)', 'BLACKJACK', 'ICE PICK',
#        'RELIC FIREARM', 'AUTOMATIC WEAPON/SUB-MACHINE GUN',
#        'ANTIQUE FIREARM', 'HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE',
#        'STRAIGHT RAZOR', 'M1-1 SEMIAUTOMATIC ASSAULT RIFLE',
#        'STARTER PISTOL/REVOLVER', 'UZI SEMIAUTOMATIC ASSAULT RIFLE',
#        'MAC-10 SEMIAUTOMATIC ASSAULT WEAPON',
#        'UNK TYPE SEMIAUTOMATIC ASSAULT RIFLE',
#        'M-14 SEMIAUTOMATIC ASSAULT RIFLE'], dtype=object)

# %% [markdown]
# It's interesting to see the variety of weapons used in crimes in Los Angeles. Would this list be similar all over the United States?

# %%
lacrime['Weapon Desc'].value_counts()
# Out:
# Weapon Desc
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    174546
# UNKNOWN WEAPON/OTHER WEAPON                        36087
# VERBAL THREAT                                      23815
# HAND GUN                                           20128
# SEMI-AUTOMATIC PISTOL                               7254
#                                                    ...
# MAC-11 SEMIAUTOMATIC ASSAULT WEAPON                    3
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    2
# HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE          2
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       2
# M1-1 SEMIAUTOMATIC ASSAULT RIFLE                       1
# Name: count, Length: 79, dtype: int64

# %% [markdown]
# Just like we saw with crimes, there are many weapons that aren't used frequently and are a small percentage of weapons used, hence the decison to only include the top 10. It's interesting to see strong arm and verbal threats on the list of weapons as defined by California and LAPD. For the analysis I decided not to include them in the top 10 because these aren't physical objects in markets.

# %% [markdown]
# ### 21 Patrol Divisions

# %% [markdown]
# The website used to download the data informs us that the LAPD has 21 community police stations also know as patrol divisions.

# %%
# The 21 police divisions in LA ordered from most to least amount of crimes
lacrime['AREA NAME'].value_counts()
# Out:
# AREA NAME
# Central        68421
# 77th Street    61153
# Pacific        58378
# Southwest      56491
# Hollywood      51726
# N Hollywood    50370
# Olympic        49416
# Southeast      49414
# Newton         48558
# Wilshire       47472
# Rampart        46184
# West LA        45031
# Northeast      42263
# Van Nuys       42245
# West Valley    41584
# Devonshire     41143
# Harbor         40754
# Topanga        40724
# Mission        39754
# Hollenbeck     36455
# Foothill       32757
# Name: count, dtype: int64

# %% [markdown]
# To make an easily digestable visual I decided to only include the top 10 of this list in the analysis. We could potentially look at the varying crimes rates per patrol division to highlight trends over time.

# %% [markdown]
# https://geohub.lacity.org/datasets/19a8293551974116b76533e984dd9260/about

# %% [markdown]
# The website above gives me the necessary geographic data to create a map of the 21 patrol divisions of Los Angeles using geopandas.

# %%
# An early iteration of what the geographical map looks like
lapd.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Time of day

# %%
# The data presents the time the crime occurred in military time
lacrime['TIME OCC']
# Out:
# 0         2130
# 1         1800
# 2         1700
# 3         2037
# 4         1200
#           ...
# 990288    1400
# 990289     100
# 990290    2330
# 990291    1500
# 990292    2300
# Name: TIME OCC, Length: 990293, dtype: int64

# %%
# Let's see what times have the most reported crimes
lacrime['TIME OCC'].value_counts().reset_index().head(10)
# Out:
#    TIME OCC  count
# 0      1200  34687
# 1      1800  26201
# 2      1700  24812
# 3      2000  24404
# 4      1900  22710
# 5      2200  22499
# 6      2100  21551
# 7      1600  20530
# 8      1500  19952
# 9      1400  17591

# %% [markdown]
# Looking at what specific times have the highest count of crimes, we see that they tend to be recorded on the hour. Could this due to indifference of actually marking down a specific time? Or is  it a coincidence? Let's take a closer look.

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=lacrime['TIME OCC'].value_counts().reset_index().sort_values(by='TIME OCC'), x='TIME OCC',y='count')
plt.xticks(range(0,2401,100))
plt.show()

# %% [markdown]
# The linegraph shows that there's a spike at the hourmark, every hour, with the biggest spike located at 12:00 pm. This could indicate that approximations were used rather than an exact time. The person reporting the crime or police officer could have just estimated the time the crime occurred.

# %%
# for the analysis I decided to divide the day into 4 equal parts
def timeofday(time):
    occ= time    
    if time >=0 and time <600:
        return 'Late night: 12am to 6am'
    if time >=600 and time <1200:
        return 'Morning: 6am to 12pm'
    if time >=1200 and time <1800:
        return 'Afternoon: 12pm to 6pm'
    if time >=1800 and time <2359:
        return 'Evening/Night: 6pm to 12am'       
# Using the function to add a new column containing time of day from time crime occurred
lacrime['Time Crime Occ']= lacrime['TIME OCC'].apply(timeofday)

# %%
# using this new column we get a better visual, in the analysis, than the one we had earlier, although more general it's easier to understand
lacrime['Time Crime Occ']
# Out:
# 0         Evening/Night: 6pm to 12am
# 1         Evening/Night: 6pm to 12am
# 2             Afternoon: 12pm to 6pm
# 3         Evening/Night: 6pm to 12am
# 4             Afternoon: 12pm to 6pm
#                      ...
# 990288        Afternoon: 12pm to 6pm
# 990289       Late night: 12am to 6am
# 990290    Evening/Night: 6pm to 12am
# 990291        Afternoon: 12pm to 6pm
# 990292    Evening/Night: 6pm to 12am
# Name: Time Crime Occ, Length: 990293, dtype: object

# %% [markdown]
# ### Days of the week

# %%
# Let's take a look at the dates the crimes occurred
lacrime['DATE OCC']
# Out:
# 0         03/01/2020 12:00:00 AM
# 1         02/08/2020 12:00:00 AM
# 2         11/04/2020 12:00:00 AM
# 3         03/10/2020 12:00:00 AM
# 4         08/17/2020 12:00:00 AM
#                    ...
# 990288    07/23/2024 12:00:00 AM
# 990289    01/15/2024 12:00:00 AM
# 990290    10/11/2024 12:00:00 AM
# 990291    04/24/2024 12:00:00 AM
# 990292    08/12/2024 12:00:00 AM
# Name: DATE OCC, Length: 990293, dtype: object

# %% [markdown]
# We can turn this into more useful information by knowing what day of the week the crime occurred.

# %%
# Adding a new column, day of the week the crime occurred
lacrime['DATE OCC']= pd.to_datetime(lacrime['DATE OCC'], format="%m/%d/%Y %I:%M:%S %p")
lacrime['Day of the Week']=lacrime['DATE OCC'].dt.day_name()
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
lacrime['Day of the Week'] = pd.Categorical(lacrime['Day of the Week'], categories=weekday_order, ordered=True)

# %%
# Creating a new dataframe grouping by time occurred and day of the week
time_day= lacrime.groupby(['TIME OCC', 'Day of the Week'],observed=False).size().reset_index(name='count')

# %%
# There's potential to see a more insightful visual highlighting specific times in days of the week that have higher crime rates
time_day
# Out:
#        TIME OCC Day of the Week  count
# 0             1          Monday   2521
# 1             1         Tuesday   2274
# 2             1       Wednesday   2416
# 3             1        Thursday   2325
# 4             1          Friday   2482
# ...         ...             ...    ...
# 10068      2359       Wednesday    108
# 10069      2359        Thursday     89
# 10070      2359          Friday    125
# 10071      2359        Saturday    120
# 10072      2359          Sunday    111
#
# [10073 rows x 3 columns]

# %%
# an attempt to see different patterns in crime rates by days of the week
plt.figure(figsize=(12,6))
sns.lineplot(data=time_day, x='TIME OCC',
             hue='Day of the Week',y='count')
plt.xticks(range(0,2401,100))
plt.show()

# %% [markdown]
# Just like our visual for count of crimes by time of day, this visual is not much more insightful.

# %%
# This is a little better but also not the best

# Creating a new dataframe to have the count grouped by time of day and day of the week
time_day1= lacrime.groupby(['Time Crime Occ', 'Day of the Week'],observed=False).size().reset_index(name='count')
plt.figure(figsize=(12,6))
sns.lineplot(data=time_day1, x='Time Crime Occ',y='count',hue='Day of the Week',sort=False)
plt.show()

# %%
# Here's a third attempt to creating an insightful visual
timeorder= ['Late night: 12am to 6am','Morning: 6am to 12pm','Afternoon: 12pm to 6pm','Evening/Night: 6pm to 12am']
sns.catplot(data=lacrime,x='Time Crime Occ',hue='Day of the Week',kind='count',height=6,aspect=2,order=timeorder)
plt.title('Time of day reported crime occured',fontsize=25)
plt.ylabel('Count of reported crimes',fontsize=20)
plt.xlabel('Time of Day',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# Though this is a better graph than the previous iteration, it's not clearest graph we could present. In the analysis I decided to give a simplier view at what days of the week have a higher crime rate.

# %% [markdown]
# ### Victim Sex

# %%
# First we look at the different possibles sexes for this data
lacrime['Vict Sex'].unique()
# Out:
# array(['M', 'X', 'F', nan, 'H', '-'], dtype=object)

# %% [markdown]
# We know that F is for female, M is for male, and X is for unknown. We'll take a look at what these unknown variables could mean.

# %%
lacrime.loc[lacrime['Vict Sex']=='-']
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 807561  232012240  06/29/2023 12:00:00 AM 2023-06-29      2115    20
#
#        AREA NAME  Rpt Dist No  Crm Cd  \
# 807561   Olympic         2091     740
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 807561  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...         0        -
#
#        Vict Descent  Premis Cd         Premis Desc Weapon Desc  Status Desc  \
# 807561            -      408.0  AUTO SUPPLY STORE*         NaN  Invest Cont
#
#                                        LOCATION              Time Crime Occ  \
# 807561  1900 S  WESTERN                      AV  Evening/Night: 6pm to 12am
#
#        Day of the Week
# 807561        Thursday

# %% [markdown]
# In this specific case vandalism doesn't necessarily have a victim and therefore we have a - for sex.

# %%
lacrime.loc[lacrime['Vict Sex']=='H'].head()
# Out:
#            DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA AREA NAME  \
# 17629  200714556  10/05/2020 12:00:00 AM 2020-10-05       200     7  Wilshire
# 21750  200708374  04/14/2020 12:00:00 AM 2020-04-14      1300     7  Wilshire
# 30536  202017825  11/29/2020 12:00:00 AM 2020-11-29      1530    20   Olympic
# 38080  200204197  01/03/2020 12:00:00 AM 2020-01-03      2200     2   Rampart
# 57093  201310830  05/13/2020 12:00:00 AM 2020-05-09      1716    13    Newton
#
#        Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 17629          769     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 21750          721     330                              BURGLARY FROM VEHICLE
# 30536         2088     626                  INTIMATE PARTNER - SIMPLE ASSAULT
# 38080          237     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 57093         1322     440                 THEFT PLAIN - PETTY ($950 & UNDER)
#
#        Vict Age Vict Sex Vict Descent  Premis Cd  \
# 17629        35        H            H      101.0
# 21750        33        H            F      101.0
# 30536        25        H            H      502.0
# 38080        25        H            F      103.0
# 57093        49        H            F      145.0
#
#                                         Premis Desc  \
# 17629                                        STREET
# 21750                                        STREET
# 30536  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 38080                                         ALLEY
# 57093                                      MAIL BOX
#
#                                           Weapon Desc  Status Desc  \
# 17629                                 PIPE/METAL PIPE  Invest Cont
# 21750                                             NaN  Invest Cont
# 30536  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Other
# 38080                                             NaN  Invest Cont
# 57093                                             NaN  Invest Cont
#
#                                       LOCATION              Time Crime Occ  \
# 17629          15TH                         ST     Late night: 12am to 6am
# 21750  8500    COLGATE                      AV      Afternoon: 12pm to 6pm
# 30536  1600    ARAPAHOE                     ST      Afternoon: 12pm to 6pm
# 38080  1600 W  2ND                          ST  Evening/Night: 6pm to 12am
# 57093  2300    WALL                         ST      Afternoon: 12pm to 6pm
#
#       Day of the Week
# 17629          Monday
# 21750         Tuesday
# 30536          Sunday
# 38080          Friday
# 57093        Saturday

# %% [markdown]
# In some cases there isn't victim for H and in others it's not very clear what the H represents, that's why it will be added to the unknown category.

# %%
# Adjusting Victim Sex column to fill in unknowns and nonapplicables with 'X'
lacrime['Vict Sex']=lacrime['Vict Sex'].replace('H','X')
lacrime['Vict Sex']=lacrime['Vict Sex'].replace('-','X')
lacrime['Vict Sex']= lacrime['Vict Sex'].fillna('X')
lacrime['Vict Sex']=lacrime['Vict Sex'].replace('F','Female')
lacrime['Vict Sex']=lacrime['Vict Sex'].replace('M','Male')

# %% [markdown]
# ### Victim Age

# %%
# Let's look at the amount of victims per age 
lacrime['Vict Age'].value_counts()
# Out:
# Vict Age
#  0      263194
#  30      21998
#  35      21516
#  31      21133
#  29      21066
#          ...
#  98         71
# -2          27
# -3           5
# -4           3
#  120         1
# Name: count, Length: 104, dtype: int64

# %% [markdown]
# We see age 0 is has the most amount of victims. There are a couple cases where age is negative, and 120 stands out as an outlier. Let's take a close look.

# %%
# Looking at some of the crime descriptions for victim age 120
lacrime[lacrime['Vict Age'] ==120]
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 196639  200808494  04/19/2020 12:00:00 AM 2020-04-19      2145     8
#
#        AREA NAME  Rpt Dist No  Crm Cd  \
# 196639   West LA          889     230
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 196639  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT       120        X
#
#        Vict Descent  Premis Cd Premis Desc            Weapon Desc  \
# 196639          NaN      101.0      STREET  SEMI-AUTOMATIC PISTOL
#
#         Status Desc                                 LOCATION  \
# 196639  Invest Cont  2000 S  BEDFORD                      ST
#
#                     Time Crime Occ Day of the Week
# 196639  Evening/Night: 6pm to 12am          Sunday

# %%
# Looking at some of the crime descriptions for victim age 0
lacrime[lacrime['Vict Age'] ==0]
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 0       190326475  03/01/2020 12:00:00 AM 2020-03-01      2130     7
# 13      221008844  05/06/2022 12:00:00 AM 2020-11-01       130    10
# 23      200412582  09/09/2020 12:00:00 AM 2020-09-09       630     4
# 26      222106031  02/23/2022 12:00:00 AM 2020-08-14      1300    21
# 27      200209713  05/03/2020 12:00:00 AM 2020-05-02      1800     2
# ...           ...                     ...        ...       ...   ...
# 990274  241406728  02/29/2024 12:00:00 AM 2024-02-28       100    14
# 990280  241513941  09/20/2024 12:00:00 AM 2024-09-16      1800    15
# 990288  240710284  07/24/2024 12:00:00 AM 2024-07-23      1400     7
# 990289  240104953  01/15/2024 12:00:00 AM 2024-01-15       100     1
# 990292  240910892  08/13/2024 12:00:00 AM 2024-08-12      2300     9
#
#           AREA NAME  Rpt Dist No  Crm Cd  \
# 0          Wilshire          784     510
# 13      West Valley         1029     510
# 23       Hollenbeck          413     510
# 26          Topanga         2113     668
# 27          Rampart          245     510
# ...             ...          ...     ...
# 990274      Pacific         1415     510
# 990280  N Hollywood         1523     420
# 990288     Wilshire          788     510
# 990289      Central          101     745
# 990292     Van Nuys          914     510
#
#                                             Crm Cd Desc  Vict Age Vict Sex  \
# 0                                      VEHICLE - STOLEN         0     Male
# 13                                     VEHICLE - STOLEN         0        X
# 23                                     VEHICLE - STOLEN         0        X
# 26           EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)         0        X
# 27                                     VEHICLE - STOLEN         0        X
# ...                                                 ...       ...      ...
# 990274                                 VEHICLE - STOLEN         0        X
# 990280  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)         0        X
# 990288                                 VEHICLE - STOLEN         0        X
# 990289         VANDALISM - MISDEAMEANOR ($399 OR UNDER)         0        X
# 990292                                 VEHICLE - STOLEN         0        X
#
#        Vict Descent  Premis Cd     Premis Desc                  Weapon Desc  \
# 0                 O      101.0          STREET                          NaN
# 13              NaN      101.0          STREET                          NaN
# 23              NaN      101.0          STREET                          NaN
# 26              NaN      203.0  OTHER BUSINESS                          NaN
# 27              NaN      101.0          STREET                          NaN
# ...             ...        ...             ...                          ...
# 990274          NaN      101.0          STREET                          NaN
# 990280          NaN      101.0          STREET                          NaN
# 990288          NaN      101.0          STREET                          NaN
# 990289            X      503.0           HOTEL  UNKNOWN WEAPON/OTHER WEAPON
# 990292          NaN      108.0     PARKING LOT                          NaN
#
#          Status Desc                                 LOCATION  \
# 0       Adult Arrest  1900 S  LONGWOOD                     AV
# 13       Invest Cont          VALJEAN                      ST
# 23       Invest Cont                         200 E  AVENUE 28
# 26       Invest Cont  7700    SAUSALITO                    AV
# 27       Invest Cont  2500 W  4TH                          ST
# ...              ...                                      ...
# 990274   Invest Cont  1300    APPLETON                     WY
# 990280   Invest Cont  6100    WHITSETT                     AV
# 990288   Invest Cont  4000 W  23RD                         ST
# 990289   Invest Cont  1300 W  SUNSET                       BL
# 990292   Invest Cont  6900    VESPER                       AV
#
#                     Time Crime Occ Day of the Week
# 0       Evening/Night: 6pm to 12am          Sunday
# 13         Late night: 12am to 6am          Sunday
# 23            Morning: 6am to 12pm       Wednesday
# 26          Afternoon: 12pm to 6pm          Friday
# 27      Evening/Night: 6pm to 12am        Saturday
# ...                            ...             ...
# 990274     Late night: 12am to 6am       Wednesday
# 990280  Evening/Night: 6pm to 12am          Monday
# 990288      Afternoon: 12pm to 6pm         Tuesday
# 990289     Late night: 12am to 6am          Monday
# 990292  Evening/Night: 6pm to 12am          Monday
#
# [263194 rows x 19 columns]

# %%
# Looking at some of the crime descriptions for victim age 1 to compare to age 0
lacrime[lacrime['Vict Age'] ==1]
# Out:
# Empty DataFrame
# Columns: [DR_NO, Date Rptd, DATE OCC, TIME OCC, AREA, AREA NAME, Rpt Dist No, Crm Cd, Crm Cd Desc, Vict Age, Vict Sex, Vict Descent, Premis Cd, Premis Desc, Weapon Desc, Status Desc, LOCATION, Time Crime Occ, Day of the Week]
# Index: []

# %%
# Looking at some of the crime descriptions for victim age 2 to compare to age 0
lacrime[lacrime['Vict Age'] ==2]
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 686     231805325  01/26/2023 12:00:00 AM 2020-01-01      1200    18
# 722     221806711  02/28/2022 12:00:00 AM 2020-01-01       700    18
# 1460    221407878  03/19/2022 12:00:00 AM 2020-01-01         1    14
# 1687    231117119  12/13/2023 12:00:00 AM 2020-01-01         1    11
# 2654    200111785  05/16/2020 12:00:00 AM 2020-05-16      1150     1
# ...           ...                     ...        ...       ...   ...
# 970900  240505211  01/31/2024 12:00:00 AM 2024-01-31      1200     5
# 971935  241205927  01/31/2024 12:00:00 AM 2024-01-31      1820    12
# 975579  241807311  03/10/2024 12:00:00 AM 2024-03-10      1200    18
# 975821  240506539  03/06/2024 12:00:00 AM 2024-03-06      1410     5
# 983096  241908384  04/30/2024 12:00:00 AM 2024-04-29      1230    19
#
#           AREA NAME  Rpt Dist No  Crm Cd  \
# 686       Southeast         1834     812
# 722       Southeast         1822     815
# 1460        Pacific         1409     815
# 1687      Northeast         1144     812
# 2654        Central          154     624
# ...             ...          ...     ...
# 970900       Harbor          504     901
# 971935  77th Street         1267     250
# 975579    Southeast         1862     237
# 975821       Harbor          566     237
# 983096      Mission         1964     237
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 686     CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         2     Male
# 722                   SEXUAL PENETRATION W/FOREIGN OBJECT         2   Female
# 1460                  SEXUAL PENETRATION W/FOREIGN OBJECT         2     Male
# 1687    CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         2   Female
# 2654                             BATTERY - SIMPLE ASSAULT         2     Male
# ...                                                   ...       ...      ...
# 970900                     VIOLATION OF RESTRAINING ORDER         2     Male
# 971935   SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT         2     Male
# 975579                     CHILD NEGLECT (SEE 300 W.I.C.)         2   Female
# 975821                     CHILD NEGLECT (SEE 300 W.I.C.)         2     Male
# 983096                     CHILD NEGLECT (SEE 300 W.I.C.)         2   Female
#
#        Vict Descent  Premis Cd                                   Premis Desc  \
# 686               B      501.0                        SINGLE FAMILY DWELLING
# 722               B      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 1460              A      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 1687              W      501.0                        SINGLE FAMILY DWELLING
# 2654              B      102.0                                      SIDEWALK
# ...             ...        ...                                           ...
# 970900            W      231.0                            DAY CARE/CHILDREN*
# 971935            B      108.0                                   PARKING LOT
# 975579            B      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 975821            B      501.0                        SINGLE FAMILY DWELLING
# 983096            H      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
#
#                                            Weapon Desc   Status Desc  \
# 686     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
# 722     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Adult Other
# 1460    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Adult Other
# 1687    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
# 2654    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
# ...                                                ...           ...
# 970900                                             NaN   Invest Cont
# 971935                                        HAND GUN  Adult Arrest
# 975579                                             NaN   Adult Other
# 975821                                             NaN   Invest Cont
# 983096                                             NaN  Adult Arrest
#
#                                         LOCATION              Time Crime Occ  \
# 686       700 E  108TH                        ST      Afternoon: 12pm to 6pm
# 722     10300 S  MAIN                         ST        Morning: 6am to 12pm
# 1460     3600    FARIS                        DR     Late night: 12am to 6am
# 1687     2000    MICHELTORENA                 ST     Late night: 12am to 6am
# 2654      500 S  MAIN                         ST        Morning: 6am to 12pm
# ...                                          ...                         ...
# 970900  21100    DALTON                       AV      Afternoon: 12pm to 6pm
# 971935   8500 S  FIGUEROA                     ST  Evening/Night: 6pm to 12am
# 975579  12000 S  MAIN                         ST      Afternoon: 12pm to 6pm
# 975821    300 W  11TH                         ST      Afternoon: 12pm to 6pm
# 983096   9200    VAN NUYS                     BL      Afternoon: 12pm to 6pm
#
#        Day of the Week
# 686          Wednesday
# 722          Wednesday
# 1460         Wednesday
# 1687         Wednesday
# 2654          Saturday
# ...                ...
# 970900       Wednesday
# 971935       Wednesday
# 975579          Sunday
# 975821       Wednesday
# 983096          Monday
#
# [429 rows x 19 columns]

# %% [markdown]
# There is a huge discrepancy in crime rates for victims aged 0, 1, and 2. It seems as if the LAPD uses 0 for instances where age may be nonapplicable. On the flipside some of these instances would actually have a victim of 0 years old. Referring back to the list of crime descriptions, we can see that some of the crimes involve a minor. Let's take a look at crimes that include words such as "child" and "minor" in the crime description and where victim age is 0.

# %%
# Finds instances where victim age is 0 and contains child, minor, or chld in the crime description
lacrime[(lacrime['Vict Age'] ==0)&(lacrime['Crm Cd Desc'].str.contains(r'child|minor|chld', case=False, na=False))]
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 1324    231008957  05/09/2023 12:00:00 AM 2020-01-09         1    10
# 2146    202007827  03/22/2020 12:00:00 AM 2020-03-22      1820    20
# 3176    201016369  12/25/2020 12:00:00 AM 2020-12-24      2200    10
# 3601    200411934  08/19/2020 12:00:00 AM 2020-08-19      1940     4
# 4168    200505526  02/05/2020 12:00:00 AM 2020-02-05      2200     5
# ...           ...                     ...        ...       ...   ...
# 986084  241011365  09/25/2024 12:00:00 AM 2024-06-15      1200    10
# 986543  241404153  01/04/2024 12:00:00 AM 2024-01-04      1130    14
# 987504  240304935  01/17/2024 12:00:00 AM 2024-01-16       700     3
# 990038  241214286  07/19/2024 12:00:00 AM 2024-07-19       700    12
# 990047  241907787  04/13/2024 12:00:00 AM 2024-04-13         1    19
#
#           AREA NAME  Rpt Dist No  Crm Cd  \
# 1324    West Valley         1028     627
# 2146        Olympic         2013     760
# 3176    West Valley         1001     235
# 3601     Hollenbeck          491     627
# 4168         Harbor          503     627
# ...             ...          ...     ...
# 986084  West Valley         1065     237
# 986543      Pacific         1483     237
# 987504    Southwest          376     235
# 990038  77th Street         1208     922
# 990047      Mission         1945     627
#
#                                         Crm Cd Desc  Vict Age Vict Sex  \
# 1324        CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT         0     Male
# 2146                LEWD/LASCIVIOUS ACTS WITH CHILD         0        X
# 3176    CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT         0        X
# 3601        CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT         0     Male
# 4168        CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT         0   Female
# ...                                             ...       ...      ...
# 986084               CHILD NEGLECT (SEE 300 W.I.C.)         0     Male
# 986543               CHILD NEGLECT (SEE 300 W.I.C.)         0   Female
# 987504  CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT         0   Female
# 990038                               CHILD STEALING         0        X
# 990047      CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT         0     Male
#
#        Vict Descent  Premis Cd                                   Premis Desc  \
# 1324              H      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 2146              X      102.0                                      SIDEWALK
# 3176              X      501.0                        SINGLE FAMILY DWELLING
# 3601              H      203.0                                OTHER BUSINESS
# 4168              H      501.0                        SINGLE FAMILY DWELLING
# ...             ...        ...                                           ...
# 986084            O      501.0                        SINGLE FAMILY DWELLING
# 986543            W      501.0                        SINGLE FAMILY DWELLING
# 987504            H      501.0                        SINGLE FAMILY DWELLING
# 990038            X      501.0                        SINGLE FAMILY DWELLING
# 990047            H      501.0                        SINGLE FAMILY DWELLING
#
#                                            Weapon Desc   Status Desc  \
# 1324    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Adult Other
# 2146                                       OTHER KNIFE   Invest Cont
# 3176                       UNKNOWN WEAPON/OTHER WEAPON  Adult Arrest
# 3601    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
# 4168    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
# ...                                                ...           ...
# 986084                                             NaN   Invest Cont
# 986543                                             NaN  Adult Arrest
# 987504                                 SCALDING LIQUID   Invest Cont
# 990038                                             NaN   Invest Cont
# 990047  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Invest Cont
#
#                                         LOCATION              Time Crime Occ  \
# 1324    16500    VANOWEN                      ST     Late night: 12am to 6am
# 2146      100 S  OXFORD                       AV  Evening/Night: 6pm to 12am
# 3176    19000    INGOMAR                      ST  Evening/Night: 6pm to 12am
# 3601     1300 S  SOTO                         ST  Evening/Night: 6pm to 12am
# 4168      900    BAYVIEW                      LN  Evening/Night: 6pm to 12am
# ...                                          ...                         ...
# 986084   5400    ZELZAH                       AV      Afternoon: 12pm to 6pm
# 986543   9400    LA TIJERA                    BL        Morning: 6am to 12pm
# 987504   1400 W  39TH                         ST        Morning: 6am to 12pm
# 990038    700 W  47TH                         ST        Morning: 6am to 12pm
# 990047  15000    CHATSWORTH                   DR     Late night: 12am to 6am
#
#        Day of the Week
# 1324          Thursday
# 2146            Sunday
# 3176          Thursday
# 3601         Wednesday
# 4168         Wednesday
# ...                ...
# 986084        Saturday
# 986543        Thursday
# 987504         Tuesday
# 990038          Friday
# 990047        Saturday
#
# [577 rows x 19 columns]

# %% [markdown]
# Because we saw there were 0 cases of where the victim age was 1, we may not be able to leave victim age for these cases equal to 0. It's possible that LAPD officers fill in an age with discretion when a minor is involved. We could however include these cases in the age group "minors". Before we make any changes, we can look for instances where the crime description contains "child" or "minor" and age is negative.

# %%
# Finds instances where victim age is negative and contains child, minor, or chld in the crime description
lacrime[(lacrime['Vict Age'] <0)&(lacrime['Crm Cd Desc'].str.contains(r'child|minor|chld', case=False, na=False))]
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 407313  241310972  07/01/2024 12:00:00 AM 2021-01-01      1200    13
#
#        AREA NAME  Rpt Dist No  Crm Cd  \
# 407313    Newton         1313     812
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 407313  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        -2   Female
#
#        Vict Descent  Premis Cd             Premis Desc  \
# 407313            H      501.0  SINGLE FAMILY DWELLING
#
#                                            Weapon Desc  Status Desc  \
# 407313  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont
#
#                                LOCATION          Time Crime Occ  \
# 407313  SANTA MONICA                 FY  Afternoon: 12pm to 6pm
#
#        Day of the Week
# 407313          Friday

# %% [markdown]
# There seems to be only one case where age is negative and the crime description describes the victim as a minor. Let's look at the other negative age cases.

# %%
# Looking at count of instances where victim age is negative
lacrime.loc[lacrime['Vict Age'] < 0]['Vict Age'].value_counts()
# Out:
# Vict Age
# -1    96
# -2    27
# -3     5
# -4     3
# Name: count, dtype: int64

# %% [markdown]
# There are 4 unique ages that are less than 0.

# %%
# Looking at some of the crime descriptions for negative victim ages
lacrime[(lacrime['Vict Age'] <0)&(lacrime['Vict Sex']=='X')]
# Out:
#             DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 142     231806653  06/12/2022 12:00:00 AM 2020-03-04       800    18
# 595     221404829  01/18/2022 12:00:00 AM 2020-07-16       300    14
# 618     221810106  04/24/2022 12:00:00 AM 2020-11-18         1    18
# 629     222007501  03/11/2022 12:00:00 AM 2020-03-11      1425    20
# 764     222019482  12/20/2022 12:00:00 AM 2020-12-20      1330    20
# ...           ...                     ...        ...       ...   ...
# 626774  240109906  03/29/2024 12:00:00 AM 2022-11-11      2216     1
# 633554  240906623  03/10/2024 12:00:00 AM 2022-06-19       922     9
# 636555  242009786  06/24/2024 12:00:00 AM 2022-10-07      1815    20
# 654277  240708202  04/18/2024 12:00:00 AM 2023-03-31      2030     7
# 728679  240706252  02/23/2024 12:00:00 AM 2023-02-22      1630     7
#
#         AREA NAME  Rpt Dist No  Crm Cd  \
# 142     Southeast         1832     946
# 595       Pacific         1487     310
# 618     Southeast         1841     845
# 629       Olympic         2033     442
# 764       Olympic         2056     745
# ...           ...          ...     ...
# 626774    Central          152     668
# 633554   Van Nuys          904     442
# 636555    Olympic         2029     442
# 654277   Wilshire          724     343
# 728679   Wilshire          738     341
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 142                             OTHER MISCELLANEOUS CRIME        -2        X
# 595                                              BURGLARY        -1        X
# 618             SEX OFFENDER REGISTRANT OUT OF COMPLIANCE        -1        X
# 629              SHOPLIFTING - PETTY THEFT ($950 & UNDER)        -1        X
# 764              VANDALISM - MISDEAMEANOR ($399 OR UNDER)        -1        X
# ...                                                   ...       ...      ...
# 626774         EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)        -1        X
# 633554           SHOPLIFTING - PETTY THEFT ($950 & UNDER)        -1        X
# 636555           SHOPLIFTING - PETTY THEFT ($950 & UNDER)        -1        X
# 654277           SHOPLIFTING-GRAND THEFT ($950.01 & OVER)        -1        X
# 728679  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...        -1        X
#
#        Vict Descent  Premis Cd         Premis Desc Weapon Desc   Status Desc  \
# 142               X      726.0     POLICE FACILITY         NaN   Invest Cont
# 595               X      203.0      OTHER BUSINESS         NaN   Invest Cont
# 618               X      726.0     POLICE FACILITY         NaN   Invest Cont
# 629               X      248.0    CELL PHONE STORE         NaN   Invest Cont
# 764               X      203.0      OTHER BUSINESS         NaN   Invest Cont
# ...             ...        ...                 ...         ...           ...
# 626774            X      744.0  HIGH-RISE BUILDING         NaN   Invest Cont
# 633554            X      404.0    DEPARTMENT STORE         NaN  Adult Arrest
# 636555            X      404.0    DEPARTMENT STORE         NaN   Adult Other
# 654277            X      415.0           THE GROVE         NaN   Invest Cont
# 728679            X      720.0  JUNIOR HIGH SCHOOL         NaN   Invest Cont
#
#                                         LOCATION              Time Crime Occ  \
# 142       100 W  108TH                        ST        Morning: 6am to 12pm
# 595      8600 S  SEPULVEDA                    BL     Late night: 12am to 6am
# 618     11200    SOUTHWEST                    BL     Late night: 12am to 6am
# 629      3700    WILSHIRE                     BL      Afternoon: 12pm to 6pm
# 764      1100 S  VERMONT                      AV      Afternoon: 12pm to 6pm
# ...                                          ...                         ...
# 626774    600 S  FIGUEROA                     ST  Evening/Night: 6pm to 12am
# 633554  14900    RAYMER                       ST        Morning: 6am to 12pm
# 636555    600 S  VIRGIL                       AV  Evening/Night: 6pm to 12am
# 654277    100    THE GROVE                    DR  Evening/Night: 6pm to 12am
# 728679    600 S  MCCADDEN                     PL      Afternoon: 12pm to 6pm
#
#        Day of the Week
# 142          Wednesday
# 595           Thursday
# 618          Wednesday
# 629          Wednesday
# 764             Sunday
# ...                ...
# 626774          Friday
# 633554          Sunday
# 636555          Friday
# 654277          Friday
# 728679       Wednesday
#
# [94 rows x 19 columns]

# %% [markdown]
# Again it seems like LAPD uses negative ages for instances where victim age may be nonapplicable. We cannot give the instances where we know a minor was involve a specific age, but we can add them to an age group. To do that we can give them an arbritrary negative age as to not skew the cases where we know the actual age.

# %%
# Find instances where age is less than or equal to 0 and crime description contains 'child', 'minor', or 'chld'
# and replaces age with -7, an arbritrary number, specific age can't be inferred but age group can
lacrime.loc[(lacrime['Vict Age'] <=0)&(lacrime['Crm Cd Desc'].str.contains(r'chld|child|minor', case=False, na=False)),'Vict Age']= -7

# %%
# Looking at some of the crime descriptions for victim age -7
lacrime[lacrime['Vict Age'] ==-7].head(3)
# Out:
#           DR_NO               Date Rptd   DATE OCC  TIME OCC  AREA  \
# 1324  231008957  05/09/2023 12:00:00 AM 2020-01-09         1    10
# 2146  202007827  03/22/2020 12:00:00 AM 2020-03-22      1820    20
# 3176  201016369  12/25/2020 12:00:00 AM 2020-12-24      2200    10
#
#         AREA NAME  Rpt Dist No  Crm Cd  \
# 1324  West Valley         1028     627
# 2146      Olympic         2013     760
# 3176  West Valley         1001     235
#
#                                       Crm Cd Desc  Vict Age Vict Sex  \
# 1324      CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT        -7     Male
# 2146              LEWD/LASCIVIOUS ACTS WITH CHILD        -7        X
# 3176  CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT        -7        X
#
#      Vict Descent  Premis Cd                                   Premis Desc  \
# 1324            H      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 2146            X      102.0                                      SIDEWALK
# 3176            X      501.0                        SINGLE FAMILY DWELLING
#
#                                          Weapon Desc   Status Desc  \
# 1324  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)   Adult Other
# 2146                                     OTHER KNIFE   Invest Cont
# 3176                     UNKNOWN WEAPON/OTHER WEAPON  Adult Arrest
#
#                                       LOCATION              Time Crime Occ  \
# 1324  16500    VANOWEN                      ST     Late night: 12am to 6am
# 2146    100 S  OXFORD                       AV  Evening/Night: 6pm to 12am
# 3176  19000    INGOMAR                      ST  Evening/Night: 6pm to 12am
#
#      Day of the Week
# 1324        Thursday
# 2146          Sunday
# 3176        Thursday

# %% [markdown]
# This shows the updated victim age for instances where we know the victim was a minor but we could not identify a specific age. Now we can create a function to split victim ages into age groups.

# %%
def agegroup(victim):
    age= victim    
    if age == -7 or age <18 and age > 0:
        return 'Minors: 0 to 17 y/o'
    if age > 17 and age < 27:
        return 'Young Adults:18 to 26 y/o'
    if age < 1:
        return 'X'
    if age < 55 and age >26:
        return 'Adults: 27 to 54 y/o'
    else:
        return 'Seniors: 55+ y/o'
# Using the function to add a new column Age Group from victim age
lacrime['Age Group']=lacrime['Vict Age'].apply(agegroup)
ageorder=['Minors: 0 to 17 y/o','Young Adults:18 to 26 y/o','Adults: 27 to 54 y/o','Seniors: 55+ y/o']

# %% [markdown]
# This function includes the cases where the victims were given the arbritrary age -7 in the "minors" age group. This is how the bar chart was created in the analysis. Now we'll see a preliminary graph of count of victims over victim age.

# %% [markdown]
# #### Victim sex and age

# %%
# Looking at the count of victims per age, excluding ages 0 and lower
agez= lacrime['Vict Age'][lacrime['Vict Age'] > 0].value_counts()
agez
# Out:
# Vict Age
# 30.0     21998
# 35.0     21516
# 31.0     21133
# 29.0     21066
# 28.0     20728
#          ...
# 95.0        99
# 96.0        95
# 97.0        72
# 98.0        71
# 120.0        1
# Name: count, Length: 99, dtype: int64

# %%
# Turning the sequence into a dataframe
agez_df= age.to_frame().reset_index()
# Ordering the rows by victim age
agez_df.sort_values(by='Vict Age',inplace=True)
#preliminary graph of victim count over victim age
sns.lineplot(data=age_df, x='Vict Age',y='count')
plt.show()

# %% [markdown]
# To make a more insightful and descriptive graph we had to split the sexes.

# %%
# Create new data frame age1z grouping victims by age and sex, and including count
age1z= lacrime.groupby(['Vict Age','Vict Sex']).size().reset_index(name='count')
age1z= age1z[(age1z['Vict Age']>0) & (age1z['Vict Sex'] != 'X')]

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data=age1z, x='Vict Age', y='count',hue='Vict Sex')
plt.title('Count of victims by age and sex',fontsize=25)
plt.xlabel('Victim Age',fontsize=20)
plt.ylabel('Count of victims',fontsize=20)
plt.show()

# %% [markdown]
# We can visually see that there exist shifts in the trend at certain intersections. We also see some interesting peakes for the males and one big peak for the the females. Let's locate these points.

# %%
# Code used to find points of interest on the lineplot
# Separate the data by sex
female_data= age1z[age1z['Vict Sex'] == 'Female'][['Vict Age','count']].rename(columns={'count':'female_count'})
male_data= age1z[age1z['Vict Sex'] == 'Male'][['Vict Age','count']].rename(columns={'count':'male_count'})

# Merge the datasets on 'Vict Age'
merged_data= pd.merge(female_data, male_data,on='Vict Age',how='inner')

# %% [markdown]
# The next step is to calculate points of interest such as peaks, maxes, and intersections.

# %%
# Find male peaks
male_peaks, _= find_peaks(merged_data['male_count'],threshold=500)
male_peak_values= merged_data.iloc[male_peaks][['Vict Age','male_count']]

# Find the maximum for female count
female_max_value= merged_data.loc[merged_data['female_count'].idxmax()]

print("Female Max Value:\n", female_max_value)
print("Male Peak Values:\n", male_peak_values)

# Calculate the difference between male and female count
merged_data['count_diff'] = merged_data['female_count'] - merged_data['male_count']

# This multiples the value in count_diff at 1 above the index and at the index and check to see if it's negative
# If it's negative there's been a change in difference therefore intersection exists
intersection_points = merged_data[(merged_data['count_diff'].shift(1) * merged_data['count_diff']) < 0]

print("Intersection Points:\n", intersection_points[['Vict Age', 'female_count', 'male_count', 'count_diff']])
# Out:
# Female Max Value:
#  Vict Age           30.0
# female_count    11113.0
# male_count      10807.0
# Name: 28, dtype: float64
# Male Peak Values:
#      Vict Age  male_count
# 28      30.0       10807
# 33      35.0       12410
# 48      50.0        7451
# Intersection Points:
#      Vict Age  female_count  male_count  count_diff
# 1        3.0           248         233          15
# 32      34.0          9497        9581         -84
# 76      78.0           795         701          94
# 77      79.0           625         634          -9
# 78      80.0           603         582          21
# 97      99.0           168         169          -1

# %% [markdown]
# We now know the age of the victims for our points of interest. The highest peak for females is at age 30. The 3 big peaks for males are at ages 30, 35, and 50. The 2 places where our male and female lines intersect and indicate a shift in the trend are ages 34 and 78. We use this information to create the graph in the analysis.

# %% [markdown]
# ### Victim Descent

# %%
# Here's a list of all the descents defined by the LAPD
replacements={'H':'Hispanic/Latin/Mexican','B':'Black','W':'White','A':'Other Asian','K':'Korean','C':'Chinese','F':'Filipino',
             'J':'Japanese','I':'American Indian/Alaskan Native','V':"Vietnamese",'S':'Samoan','P':'Pacific Islander',
             'Z':'Asian Indian','G':'Guamanian','U':'Hawaiian','D':'Cambodain','L':'Laotian','X':'Unknown','O':'Other'}
replacements
# Out:
# {'H': 'Hispanic/Latin/Mexican',
#  'B': 'Black',
#  'W': 'White',
#  'A': 'Other Asian',
#  'K': 'Korean',
#  'C': 'Chinese',
#  'F': 'Filipino',
#  'J': 'Japanese',
#  'I': 'American Indian/Alaskan Native',
#  'V': 'Vietnamese',
#  'S': 'Samoan',
#  'P': 'Pacific Islander',
#  'Z': 'Asian Indian',
#  'G': 'Guamanian',
#  'U': 'Hawaiian',
#  'D': 'Cambodain',
#  'L': 'Laotian',
#  'X': 'Unknown',
#  'O': 'Other'}

# %% [markdown]
# We can see the limitations of this list as it doesn't include all of the possible descents in LA.

# %%
lacrime['Vict Descent'].value_counts()
# Out:
# Vict Descent
# H    293692
# W    198501
# B    134685
# X    104534
# O     77172
# A     21131
# K      5772
# F      4643
# C      4397
# J      1524
# V      1139
# I       986
# Z       544
# P       280
# U       212
# D        88
# L        74
# G        72
# S        56
# -         2
# Name: count, dtype: int64

# %% [markdown]
# There's a big disparity in victims per descent after the top 6. It's clearer to see a list for the top 5 in this case. Also, I decided to exclude unknown (X) and other asian (A) because it didn't help paint a clear picture of what descents make up the most amount of victims.

# %% [markdown]
# ### Statuses of the cases

# %%
# Looking at the possible values for the Status Description column
lacrime['Status Desc'].unique()
# Out:
# array(['Adult Arrest', 'Invest Cont', 'Adult Other', 'Juv Arrest',
#        'Juv Other', 'UNK'], dtype=object)

# %%
lacrime['Status Desc'].value_counts()
# Out:
# Status Desc
# Invest Cont     791574
# Adult Other     107976
# Adult Arrest     85676
# Juv Arrest        3215
# Juv Other         1845
# UNK                  7
# Name: count, dtype: int64

# %% [markdown]
# Looking at the numbers, Investigation Continued makes up the majority of the statuses of these cases. Adult other isn't defined on the webiste but could be made up of warnings, fines, and other possibilities that don't fall under arrest.

# %% [markdown]
# ### Years

# %%
# Looking at the dates the crime occurred
lacrime['DATE OCC']
# Out:
# 0        2020-03-01
# 1        2020-02-08
# 2        2020-11-04
# 3        2020-03-10
# 4        2020-08-17
#             ...
# 990288   2024-07-23
# 990289   2024-01-15
# 990290   2024-10-11
# 990291   2024-04-24
# 990292   2024-08-12
# Name: DATE OCC, Length: 990293, dtype: datetime64[ns]

# %%
# Adding a new column, year crime occurred
lacrime['Year']= pd.DatetimeIndex(lacrime['DATE OCC']).year

# %%
lacrime['Year'].value_counts()
# Out:
# Year
# 2022    235189
# 2023    232216
# 2021    209831
# 2020    199806
# 2024    113251
# Name: count, dtype: int64

# %% [markdown]
# We can see the count of crimes per year and it's peak is in 2022. It's important to note that 2024 is the lowest, as of November 2024. We would have to see and update once the year is over.

# %% [markdown]
# ### Miscellaneous

# %%
# Create the catplot
g = sns.catplot(data=lacrime_df, x='Status Desc', kind='count', height=4, aspect=2)

# Set the title and labels
plt.title('Status of reported crime', fontsize=25)
plt.xlabel('Status', fontsize=20)
plt.ylabel('Count of reported crime', fontsize=20)

# Add values on top of the bars
for ax in g.axes.flat:
    for p in ax.patches:
        ax.annotate(f'{p.get_height():,.0f}',  # Add the height value (count) on top of the bar
                    (p.get_x() + p.get_width() / 2., p.get_height()),  # Position of the annotation
                    ha='center', va='center', fontsize=12, color='black',  # Style of the annotation
                    xytext=(0, 5), textcoords='offset points')  # Position adjustment

# Show the plot
plt.show()

# %%
# Set Seaborn style for Seaborn plots
sns.set_style('whitegrid')  # Apply style to all other Seaborn plots

# Example: Plot a Seaborn plot (not geospatial)
# You can replace this with any other Seaborn plot you want
plt.figure(figsize=(12, 8))
sns.lineplot(x=[1, 2, 3], y=[1, 2, 3], label="Example Lineplot")
plt.title('Seaborn Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# Now plot the geospatial map, reset the style for the map only
# Reset the background and grid properties explicitly for the map
plt.style.use('ggplot')  # This prevents any background/grid issues



# Create the map plot
fig, ax = plt.subplots(figsize=(12, 8))  # Create a specific figure and axis for the map

# Plot geospatial data (density map)
lapdareas.plot(ax=ax)  # Adjust the map colors if needed

# Manually set the title and axis labels (optional)
ax.set_title('Density Map', fontsize=25)
ax.set_xlabel('Longitude', fontsize=15)
ax.set_ylabel('Latitude', fontsize=15)

# Optionally remove axis ticks if they are causing problems (you can customize this)
ax.set_xticks([])  # Removes x-axis ticks
ax.set_yticks([])  # Removes y-axis ticks

# Show the map plot
plt.show()

# %%
# Create the countplot
plt.figure(figsize=(12, 6))  # Optional: set the figure size
ax = sns.countplot(
    data=lacrime_df[lacrime_df['Age Group'] != 'X'], 
    x='Age Group', 
    order=ageorder  # Ensure the bars are ordered by age group
)

# Set the title and labels
plt.title('Count of Victims by Age Group', fontsize=25)
plt.xlabel('Age Group', fontsize=20)
plt.ylabel('Count of Victims', fontsize=20)

# Annotate the bars with values above them
for p in ax.patches:  # Loop through each bar (patch)
    ax.text(p.get_x() + p.get_width() / 2,  # X-coordinate: center of the bar
            p.get_height() + 2,  # Y-coordinate: slightly above the bar
            f'{int(p.get_height())}',  # Value to display above the bar
            ha='center', va='bottom', fontsize=12)  # Center alignment and font size

plt.show()

# %%
# Your existing data and catplot
crimes = lacrime_df.pivot_table(index='Crm Cd Desc',
                                aggfunc='size').reset_index(name='Number of cases').sort_values(by='Number of cases', ascending=False)

# Create the catplot
cat_plot = sns.catplot(data=crimes.head(10), x='Number of cases', y='Crm Cd Desc', height=5, aspect=2, kind='bar')
cat_plot.fig.suptitle("Top 10 Crimes reported", fontsize=25)  # Title for the FacetGrid
cat_plot.set_axis_labels('Count of reported crimes', 'Crime Description', fontsize=20)

# Adding the average line
averagec = round(crimes['Number of cases'].head(10).mean(), 2)
for ax in cat_plot.axes.flat:  # Handles all subplots in case there are multiple
    ax.axvline(averagec, color='red', linestyle='--', label=f'Top 10 Average: {averagec}')
    ax.legend()

    # Annotate bars with values
    for p in ax.patches:  # Loop through the bars
        ax.text(p.get_width() + 2,  # X-coordinate: slightly offset from the end of the bar
                p.get_y() + p.get_height() / 2,  # Y-coordinate: center of the bar
                f'{int(p.get_width())}',  # Text: the width of the bar (value)
                va='center', fontsize=12)  # Center alignment and font size

plt.show()

# %%
# Data preparation
crimes = lacrime_df.pivot_table(index='Crm Cd Desc',
                                aggfunc='size').reset_index(name='Number of cases').sort_values(by='Number of cases', ascending=False)

# Create the barplot
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=crimes.head(10), x='Number of cases', y='Crm Cd Desc')

# Add title and labels
plt.title("Top 10 Crimes reported", fontsize=25)
plt.xlabel('Count of reported crimes', fontsize=20)
plt.ylabel('Crime Description', fontsize=20)

# Add the average line
averagec = round(crimes['Number of cases'].head(10).mean(), 2)
plt.axvline(averagec, color='red', linestyle='--', label=f'Top 10 Average: {averagec}')
plt.legend()

# Annotate bars with values
for p in ax.patches:  # Loop through the bars
    ax.text(p.get_width() + 2,  # X-coordinate: slightly offset from the end of the bar
            p.get_y() + p.get_height() / 2,  # Y-coordinate: center of the bar
            f'{int(p.get_width())}',  # Display the width (value) as an integer
            va='center', fontsize=12)  # Center alignment and font size

plt.tight_layout()
plt.show()

# %%
age= lacrime_df['Vict Age'][lacrime_df['Vict Age'] > 0].value_counts()
age_df= age.to_frame().reset_index()
age_df.sort_values(by='Vict Age',inplace=True)

# %%
age= lacrime_df['Vict Age'][lacrime_df['Vict Age'] > 0].value_counts()
age_df= age.to_frame().reset_index()
age_df.sort_values(by='Vict Age',inplace=True)
sns.lineplot(data=age_df, x='Vict Age',y='count',hue=)
plt.show()

# %%
age1= lacrime_df.groupby(['Vict Age','Vict Sex']).size().reset_index(name='count')

age1= age1[(age1['Vict Age']>0) & (age1['Vict Sex'] != 'X')]

# %%
age1[age1['Vict Sex']=='Female'].max()
# Out:
# Vict Age        99
# Vict Sex    Female
# count        11113
# dtype: object

# %%
age1[age1['count']==11113]
# Out:
#     Vict Age Vict Sex  count
# 97        30   Female  11113

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data=age1, x='Vict Age', y='count',hue='Vict Sex')
plt.title('Count of victims by age and sex',fontsize=25)
plt.xlabel('Victim Age',fontsize=20)
plt.ylabel('Count of victims',fontsize=20)
plt.show()

# %%
## old method to find peaks

# Find peaks for female data
female_peaks, _ = find_peaks(age1[age1['Vict Sex'] == 'Female']['count'])
female_peak_values = age1[age1['Vict Sex'] == 'Female'].iloc[female_peaks]

# Find peaks for male data
male_peaks, _ = find_peaks(age1[age1['Vict Sex'] == 'Male']['count'])
male_peak_values = age1[age1['Vict Sex'] == 'Male'].iloc[male_peaks]

print("Female Peak Values:\n", female_peak_values)
print("Male Peak Values:\n", male_peak_values)
# Out:
# Female Peak Values:
#       Vict Age Vict Sex  count
# 25          5   Female    308
# 94         28   Female  10971
# 100        30   Female  11113
# 151        47   Female   5440
# 160        50   Female   5105
# 256        82   Female    492
# Male Peak Values:
#       Vict Age Vict Sex  count
# 20          3     Male    233
# 101        30     Male  10807
# 116        35     Male  12410
# 125        38     Male   8686
# 152        47     Male   6231
# 161        50     Male   7451
# 170        53     Male   5685
# 191        60     Male   4656

# %%
## finding leanest code
# Separate the data by sex
female_data = age1[age1['Vict Sex'] == 'Female'][['Vict Age', 'count']].rename(columns={'count': 'female_count'})
male_data = age1[age1['Vict Sex'] == 'Male'][['Vict Age', 'count']].rename(columns={'count': 'male_count'})

# Merge the datasets on 'Vict Age'
merged_data = pd.merge(female_data, male_data, on='Vict Age', how='inner')

# Find male peaks
male_peaks, _ = find_peaks(merged_data['male_count'],threshold=500)
male_peak_values = merged_data.iloc[male_peaks][['Vict Age', 'male_count']]

# Find the maximum for female count
female_max_value = merged_data.loc[merged_data['female_count'].idxmax()]

#calculate the difference and find intersections
# we use this to find major intersection, code in eda but not need to actually plot point
merged_data['count_diff'] = merged_data['female_count'] - merged_data['male_count']
intersection_points = merged_data[(merged_data['count_diff'].shift(1) * merged_data['count_diff']) < 0]

# %%
#prints info we need to know
# Separate the data by sex
female_data = age1[age1['Vict Sex'] == 'Female'][['Vict Age', 'count']].rename(columns={'count': 'female_count'})
male_data = age1[age1['Vict Sex'] == 'Male'][['Vict Age', 'count']].rename(columns={'count': 'male_count'})

# Merge the datasets on 'Vict Age'
merged_data = pd.merge(female_data, male_data, on='Vict Age', how='inner')

# Find peaks
male_peaks, _ = find_peaks(merged_data['male_count'],threshold=500)
male_peak_values = merged_data.iloc[male_peaks][['Vict Age', 'male_count']]

# Find the maximum for female count
female_max_value = merged_data.loc[merged_data['female_count'].idxmax()]

print("Female Max Value:\n", female_max_value)
print("Male Peak Values:\n", male_peak_values)


# Calculate the difference and find intersections
merged_data['count_diff'] = merged_data['female_count'] - merged_data['male_count']
#this multiples the value in count_diff at 1 above the index and at the index and check to see if it's negative
#if its' negative theres been a change in difference therefore intersection exists
intersection_points = merged_data[(merged_data['count_diff'].shift(1) * merged_data['count_diff']) < 0]

print("Intersection Points:\n", intersection_points[['Vict Age', 'female_count', 'male_count', 'count_diff']])
# Out:
# Female Max Value:
#  Vict Age           30
# female_count    11113
# male_count      10807
# Name: 28, dtype: int64
# Male Peak Values:
#      Vict Age  male_count
# 28        30       10807
# 33        35       12410
# 48        50        7451
# Intersection Points:
#      Vict Age  female_count  male_count  count_diff
# 1          3           248         233          15
# 32        34          9497        9581         -84
# 76        78           795         701          94
# 77        79           625         634          -9
# 78        80           603         582          21
# 97        99           168         169          -1

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data=merged_data, x='Vict Age', y='female_count', label='Female')
sns.lineplot(data=merged_data, x='Vict Age', y='male_count', label='Male')

# Plot peaks
plt.scatter(male_peak_values['Vict Age'], male_peak_values['male_count'], color='orange', label='Male Peaks')
plt.scatter(female_max_value['Vict Age'], female_max_value['female_count'], color='purple', label='Female Max', marker='o')
plt.scatter(34,9497, color='green', label='Major Intersection')

# Plot intersections
plt.scatter(intersection_points['Vict Age'], intersection_points['female_count'], color='red', label='Intersections')
plt.scatter(29,7000)

plt.title('Count of victims by age and sex')
plt.xlabel('Victim Age')
plt.ylabel('Count of victims')
plt.legend()
plt.show()

# %%
sns.catplot(data=lacrime_df[(lacrime_df['Vict Sex'] !='X') & (lacrime_df['Age Group'] !='X')],
            x='Age Group', hue='Vict Sex', kind='count',height=7, aspect=2, order=ageorder)
plt.title('Count of reported crimes by age group & sex',fontsize=25)
plt.xlabel('Age Group', fontsize=20)
plt.ylabel('Count of reported crimes',fontsize=20)
plt.show()

# %%
# seperately they give us the total of investigation continued and investigation complete
lacrime_df['Status Desc'][lacrime_df['Status Desc'] == 'Invest Cont'].value_counts().sum()
lacrime_df['Status Desc'][lacrime_df['Status Desc'] != 'Invest Cont'].value_counts().sum()
# Out:
# np.int64(198719)

# %%
# attempt to make the information more honest
# im looking at the time the victim is age 0 or less because these are the instances that I just got rid off
# I also filtered for instances the victime did not have a known sex

# what I need to figure out is not the sex, I can't infer that with the crime
#what I want to know is how many of these ages can we toss into the minor category, can get much more specific than that
#also we have to make sure it doesn't affect our graph because we don't know their age

# so age less than zero and with 'minor' or 'child'/ then give them age of 0.1 so they fall in the minor category
# but they are easy to leave out for the graph

# I want to change the age of vict age 0 with 'child' in crime desc to age 0.5
#I will include in age group, won't include in graph, age seems to be filled under police discretion

#zero wasn't included because victim age was nonapplicable or specific age and age group could not be infered

# %%
'CRUELTY TO ANIMALS'
'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM'

'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)'
'CHILD ANNOYING (17YRS & UNDER)'
'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT'
'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT'
'CHILD STEALING'
'LEWD/LASCIVIOUS ACTS WITH CHILD'
'CHILD NEGLECT (SEE 300 W.I.C.)'
'CHILD PORNOGRAPHY'
'DRUGS, TO A MINOR'
'CHILD ABANDONMENT'
# Out:
# 'CHILD ABANDONMENT'
